# %% [markdown]
# # animal
# ## ߓߌߦߊ߲

# %%
# HIDDEN
import kukukan
import pandas as pd
from IPython.display import HTML
from kukukan import image,sound

df = pd.DataFrame({
   'ߖߊ': [
            image.player(1,"ߛߏߛߏ߮",'animal'),
            image.player(2,"xxx",'animal'),
            image.player(3,"xxx",'animal'),
            image.player(4,"ߕߏߕߏ",'animal'),
            image.player(5,"ߦߌߣߍ߮",'animal'),
            image.player(6,"ߛߊߡߊ߮",'animal'),
            image.player(7,"ߖߌߙߌߛߎ߲ߓߊ߮",'animal'),
            image.player(8,"ߛߊ߮",'animal'),
            image.player(9,'ߥߊߙߊ߮','animal'),
            image.player(10,'ߓߊߛߊ߮','animal'),
            image.player(11,'ߒߕߏߙߌ','animal'),
            image.player(12,'ߓߊ߮','animal'),
            image.player(13,'ߓߊ߲ߓߊ߮','animal'),
            image.player(14,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(15,'ߘߎߥߊ߮','animal'),  
            image.player(16,'ߒߕߏߙߌ','animal'),
            image.player(17,'ߓߊ߮','animal'),
            image.player(18,'ߓߊ߲ߓߊ߮','animal'),
            image.player(19,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(20,'ߘߎߥߊ߮','animal'), 
            image.player(21,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(22,'ߘߎߥߊ߮','animal'), 
            image.player(23,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(24,'ߘߎߥߊ߮','animal'),
            image.player(25,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(26,'ߘߎߥߊ߮','animal'),  
            image.player(27,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(28,'ߘߎߥߊ߮','animal'), 
            image.player(29,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(30,'ߘߎߥߊ߮','animal'), 
            image.player(31,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(32,'ߘߎߥߊ߮','animal'), 
            image.player(33,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(34,'ߘߎߥߊ߮','animal'), 
            image.player(35,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(36,'ߘߎߥߊ߮','animal'), 
            image.player(37,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(38,'ߘߎߥߊ߮','animal'),   
            image.player(39,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(40,'ߘߎߥߊ߮','animal'),  
            image.player(41,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(42,'ߘߎߥߊ߮','animal'), 
            image.player(43,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(44,'ߘߎߥߊ߮','animal'),
            image.player(45,'ߘߎߥߊ߮','animal'), 
            image.player(46,'ߘߎߥߊ߮','animal'),
       
             ],

        'Name': [
            'Mosquito',
            'Ant',
            'Chameleon',
            'Salamander',
            'Bee',
            'Mouse',
            'Rat',
            'Kangoroo',
            'Snake',
            'Dolphin',
            'Fox',
            'Frog',
            'Pellican',
            'Elephant',
            'Pig',
            'Vulture',
            'Human',
            'Flying snake',
            'Pandas',
            'Tiger' ,
            'Cat',
            'Dog',
            'Squid',
            'Octopus',
            'Bed Bug',
            'Praying Mantis',
            'Monkey',
            'Gorilla',
            'Butterfly',
            'Crododile',
            'Antilope',
            'Hippopotamus',
            'Alligator',
            'Fox',
            'Eagle',
            'Camel',
            'Mangoose',
            'Squirl',
            'Sloth',
            'Warhog',
            'Shark',
            'Whale',
            'Spider',
            'Bufallo',
            'Marabu',
            'Owl'
             ],
})


HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ߖߊ</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/image/animal/1.jpg" alt="ߛߏߛߏ߮" width="150" height="150"></td>
#       <td>Mosquito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/image/animal/2.jpg" alt="xxx" width="150" height="150"></td>
#       <td>Ant</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/image/animal/3.jpg" alt="xxx" width="150" height="150"></td>
#       <td>Chameleon</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
