# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

# %%
G.add_node(1)
G.add_nodes_from([2, 3])
G.add_nodes_from([(4, {"color": "red"}), (5, {"color": "green"})])

G.add_edge(1, 2)
e = (2, 3)
G.add_edge(*e)  # unpack edge tuple*
G.add_edges_from([(1, 2), (1, 3)])

# %%
H = nx.path_graph(10)
G.add_nodes_from(H)

# %%
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
plt.show()

# %%
import pydo
graph mygraph {
    bgcolor="yellow";
    a [label="Foo"];
    b [shape=circle];
    a -- b -- c [color=blue];
}
# Out:
#   Cell In[6], line 2
#     graph mygraph {
#           ^
# SyntaxError: invalid syntax

# %%
import pydot

graphs = pydot.graph_from_dot_file("example.dot")
graph = graphs[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 import pydot
# ----> 3 graphs = pydot.graph_from_dot_file("example.dot")
#       4 graph = graphs[0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pydot/core.py:438, in graph_from_dot_file(path, encoding)
#     428 def graph_from_dot_file(path, encoding=None):
#     429     """Load graphs from DOT file at `path`.
#     430
#     431     @param path: to DOT file
#    (...)
#     436     @rtype: `list` of `pydot.Dot`
#     437     """
# --> 438     with open(path, encoding=encoding) as f:
#     439         s = f.read()
#     440     graphs = graph_from_dot_data(s)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.dot'

# %%
import pydot

graph = pydot.Dot("my_graph", graph_type="graph", bgcolor="yellow")

# Add nodes
my_node = pydot.Node("a", label="Foo")
graph.add_node(my_node)
# Or, without using an intermediate variable:
graph.add_node(pydot.Node("b", shape="circle"))

# Add edges
my_edge = pydot.Edge("a", "b", color="blue")
graph.add_edge(my_edge)
# Or, without using an intermediate variable:
graph.add_edge(pydot.Edge("b", "c", color="blue"))
graph

# %%
graph.write_png("output.png")

# %%
output_graphviz_svg = graph.create_svg()

# %%
keras,tensorflow,skitlearn, machine learning book

# %%
import pygraphviz as pgv

# %%
G = pgv.AGraph(ranksep="0.1")
G.add_node(1, color="red")
G.add_edge("b", "c", color="blue")
G.layout()
G.draw("file.png")
