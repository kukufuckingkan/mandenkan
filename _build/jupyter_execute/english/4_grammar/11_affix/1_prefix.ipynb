# %% [markdown]
# # Prefix
# ## ߦߍߕߎ߲

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML
from kukukan import image,sound,panda

# Define headers and values (as lists)
headers = ['name', 'nko', 'pronounciation', 'nko pronouncition']
values = [
    ['tun', 'Connect', '',''],
    ['tunli', '', '',''],
    ['tunni', 'Connection', '',''],    
    ['tunta', 'Connectable', '',''],
    ['tunna', '', '',''],
    ['tunma', 'Connector (person)', '',''],
    ['tunnen', '', '',''],
    ['tuntoh', '', '',''], 
    ['tunra', '', '',''],
    ['tundi', '', '',''],
    ['faa', '', '',''],  
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)
coloredDf = panda.colors(df,[3,5],'red')


HTML(coloredDf.to_html(escape=False))
# Out:
# <style type="text/css">
# #T_0615e_row2_col0, #T_0615e_row2_col1, #T_0615e_row2_col2, #T_0615e_row2_col3, #T_0615e_row4_col0, #T_0615e_row4_col1, #T_0615e_row4_col2, #T_0615e_row4_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_0615e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0615e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_0615e_level0_col1" class="col_heading level0 col1" >nko</th>
#       <th id="T_0615e_level0_col2" class="col_heading level0 col2" >pronounciation</th>
#       <th id="T_0615e_level0_col3" class="col_heading level0 col3" >nko pronouncition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0615e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0615e_row0_col0" class="data row0 col0" >tun</td>
#       <td id="T_0615e_row0_col1" class="data row0 col1" >Connect</td>
#       <td id="T_0615e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_0615e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0615e_row1_col0" class="data row1 col0" >tunli</td>
#       <td id="T_0615e_row1_col1" class="data row1 col1" ></td>
#       <td id="T_0615e_row1_col2" class="data row1 col2" ></td>
#       <td id="T_0615e_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0615e_row2_col0" class="data row2 col0" >tunni</td>
#       <td id="T_0615e_row2_col1" class="data row2 col1" >Connection</td>
#       <td id="T_0615e_row2_col2" class="data row2 col2" ></td>
#       <td id="T_0615e_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0615e_row3_col0" class="data row3 col0" >tunta</td>
#       <td id="T_0615e_row3_col1" class="data row3 col1" >Connectable</td>
#       <td id="T_0615e_row3_col2" class="data row3 col2" ></td>
#       <td id="T_0615e_row3_col3" class="data row3 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0615e_row4_col0" class="data row4 col0" >tunna</td>
#       <td id="T_0615e_row4_col1" class="data row4 col1" ></td>
#       <td id="T_0615e_row4_col2" class="data row4 col2" ></td>
#       <td id="T_0615e_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0615e_row5_col0" class="data row5 col0" >tunma</td>
#       <td id="T_0615e_row5_col1" class="data row5 col1" >Connector (person)</td>
#       <td id="T_0615e_row5_col2" class="data row5 col2" ></td>
#       <td id="T_0615e_row5_col3" class="data row5 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0615e_row6_col0" class="data row6 col0" >tunnen</td>
#       <td id="T_0615e_row6_col1" class="data row6 col1" ></td>
#       <td id="T_0615e_row6_col2" class="data row6 col2" ></td>
#       <td id="T_0615e_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0615e_row7_col0" class="data row7 col0" >tuntoh</td>
#       <td id="T_0615e_row7_col1" class="data row7 col1" ></td>
#       <td id="T_0615e_row7_col2" class="data row7 col2" ></td>
#       <td id="T_0615e_row7_col3" class="data row7 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0615e_row8_col0" class="data row8 col0" >tunra</td>
#       <td id="T_0615e_row8_col1" class="data row8 col1" ></td>
#       <td id="T_0615e_row8_col2" class="data row8 col2" ></td>
#       <td id="T_0615e_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0615e_row9_col0" class="data row9 col0" >tundi</td>
#       <td id="T_0615e_row9_col1" class="data row9 col1" ></td>
#       <td id="T_0615e_row9_col2" class="data row9 col2" ></td>
#       <td id="T_0615e_row9_col3" class="data row9 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_0615e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0615e_row10_col0" class="data row10 col0" >faa</td>
#       <td id="T_0615e_row10_col1" class="data row10 col1" ></td>
#       <td id="T_0615e_row10_col2" class="data row10 col2" ></td>
#       <td id="T_0615e_row10_col3" class="data row10 col3" ></td>
#     </tr>
#   </tbody>
# </table>
