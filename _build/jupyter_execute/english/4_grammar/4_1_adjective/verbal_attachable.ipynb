# %% [markdown]
# # verbal attachable

# %%
# HIDDEN
import kukukan
import pandas as pd
from IPython.display import HTML
from kukukan import player

df = pd.DataFrame({
      'nko verb' : ['ߕߎ߲',
              'ߋ',
              'ߌ',
              'ߍ',
              'ߎ',
              'ߏ',
              'ߐ',
             ],
    'nko sound': 
    [
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),        
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    ],
    
    'nko adjective': ['ߕߎ߲ߟߌ',
              'ߕߎ߲ߟߌ',
              'ߌ',
              'ߍ',
              'ߎ',
              'ߏ',
              'ߐ',
             ],
    
    'nko Sound': 
    [
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),        
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    ],


        'english verb': ['To Connect',
              'To Connect',
              'ߌ',
              'ߍ',
              'ߎ',
              'ߏ',
              'ߐ',
             ],
    
    'english Sound': 
    [
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),        
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    ],

    'english adjective': ['Connection',
      '',
      'ߌ',
      'ߍ',
      'ߎ',
      'ߏ',
      'ߐ',
     ],
    
    'english adjectif sound': 
    [
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),        
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    player.play('resource/asset/audio/1_kan.mp3','DEV'),
    ]
})


HTML(df.to_html(escape=False,index=False))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 from IPython.display import HTML
# ----> 5 from kukukan import player
#       7 df = pd.DataFrame({
#       8       'nko verb' : ['ߕߎ߲',
#       9               'ߋ',
#    (...)
#      86     ]
#      87 })
#      90 HTML(df.to_html(escape=False,index=False))
#
# ImportError: cannot import name 'player' from 'kukukan' (/opt/anaconda3/lib/python3.11/site-packages/kukukan/__init__.py)
