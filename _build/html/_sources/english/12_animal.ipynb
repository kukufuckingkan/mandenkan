# %% [markdown]
# # animal
# ## ߓߌߦߊ߲

# %%
# HIDDEN
import kukukan
import pandas as pd
from IPython.display import HTML
from kukukan import player, image

df = pd.DataFrame({
   'ߖߊ': [
            image.showHtml(1,"ߛߏߛߏ߮"),
            image.showHtml(2,"xxx"),
            image.showHtml(3,"xxx"),
            image.showHtml(4,"ߕߏߕߏ"),
            image.showHtml(5,"ߦߌߣߍ߮"),
            image.showHtml(6,"ߛߊߡߊ߮"),
            image.showHtml(7,"ߖߌߙߌߛߎ߲ߓߊ߮"),
            image.showHtml(8,"ߛߊ߮"),
            image.showHtml(9,'ߥߊߙߊ߮'),
            image.showHtml(10,'ߓߊߛߊ߮'),
            image.showHtml(11,'ߒߕߏߙߌ'),
            image.showHtml(12,'ߓߊ߮'),
            image.showHtml(13,'ߓߊ߲ߓߊ߮'),
            image.showHtml(14,'ߝߐ߲ߝߐ߲ߣߍ߲'),
            image.showHtml(15,'ߘߎߥߊ߮'),       
             ],
    
    'ߕߐ߮': [
            'ߛߏߛߏ߮',
            'xxxx',
            'xxx',
            'ߕߏߕߏ߮',
            'ߦߌߣߍ߮',
            'ߛߊߡߊ߮',
            'ߖߌߙߌߛߎ߲ߓߊ߮',
            'ߛߊ߮',
            'ߥߊߙߊ߮',
            'ߓߊߛߊ߮',
            'ߒߕߏߙߌ',
            'ߓߊ߮',
            'ߓߊ߲ߓߊ߮',
            'ߝߐ߲ߝߐ߲ߣߍ߲',
            'ߘߎߥߊ߮'
             ],
    
    'ߞߊ߲': 
    [
    player.playFromGitt('VOWEL',1),       
    player.playFromGitt('VOWEL',2),
    player.playFromGitt('VOWEL',3),
    player.playFromGitt('VOWEL',4),
    player.playFromGitt('VOWEL',5),
    player.playFromGitt('VOWEL',6), 
    player.playFromGitt('VOWEL',7),
    player.playFromGitt('VOWEL',8),
    player.playFromGitt('VOWEL',9),
    player.playFromGitt('VOWEL',10),  
    player.playFromGitt('VOWEL',11),
    player.playFromGitt('VOWEL',12),
    player.playFromGitt('VOWEL',13), 
    player.playFromGitt('VOWEL',14),
    player.playFromGitt('VOWEL',15),         
    ],

        'Name': [
            'Mosquito',
            'xxx',
            'Chameleon',
            'Rat',
            'Mouse',
            'Elephant',
            'Hippopotamus',
            'Snake',
            'Lion',
            'Lizard',
            'Frog',
            'Goat',
            'Crododile',
            'Viper',
            'Vulture'
             ],
    
    'Pronounciation': 
    [
    player.playFromGitt('VOWEL',1),
    player.playFromGitt('VOWEL',2),  
    player.playFromGitt('VOWEL',3), 
    player.playFromGitt('VOWEL',4),
    player.playFromGitt('VOWEL',5),
    player.playFromGitt('VOWEL',6),
    player.playFromGitt('VOWEL',7),
    player.playFromGitt('VOWEL',8),  
    player.playFromGitt('VOWEL',9), 
    player.playFromGitt('VOWEL',10), 
    player.playFromGitt('VOWEL',11),  
    player.playFromGitt('VOWEL',12),
    player.playFromGitt('VOWEL',13),
    player.playFromGitt('VOWEL',14),
    player.playFromGitt('VOWEL',15),        
    ]
})


HTML(df.to_html(escape=False,index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ߖߊ</th>
#       <th>ߕߐ߮</th>
#       <th>ߞߊ߲</th>
#       <th>Name</th>
#       <th>Pronounciation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/image/1.jpg" alt="ߛߏߛߏ߮" width="150" height="150"></td>
#       <td>ߛߏߛߏ߮</td>
#       <td><audio controls style="width:150px">\n                    <source src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/vowel/1.mp3" type="audio/mpeg">\n                    Your browser does not support the audio element.\n                </audio></td>
#       <td>Mosquito</td>
# ...
