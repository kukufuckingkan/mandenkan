# %% [markdown]
# # animal
# ## ߓߌߦߊ߲

# %%
# HIDDEN
import kukukan
import pandas as pd
from IPython.display import HTML
from kukukan import image,sound

df = pd.DataFrame({
   'ߖߊ': [
            image.player(1,"ߛߏߛߏ߮",'animal'),
            image.player(2,"xxx",'animal'),
            image.player(3,"xxx",'animal'),
            image.player(4,"ߕߏߕߏ",'animal'),
            image.player(5,"ߦߌߣߍ߮",'animal'),
            image.player(6,"ߛߊߡߊ߮",'animal'),
            image.player(7,"ߖߌߙߌߛߎ߲ߓߊ߮",'animal'),
            image.player(8,"ߛߊ߮",'animal'),
            image.player(9,'ߥߊߙߊ߮','animal'),
            image.player(10,'ߓߊߛߊ߮','animal'),
            image.player(11,'ߒߕߏߙߌ','animal'),
            image.player(12,'ߓߊ߮','animal'),
            image.player(13,'ߓߊ߲ߓߊ߮','animal'),
            image.player(14,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(15,'ߘߎߥߊ߮','animal'),  
            image.player(16,'ߒߕߏߙߌ','animal'),
            image.player(17,'ߓߊ߮','animal'),
            image.player(18,'ߓߊ߲ߓߊ߮','animal'),
            image.player(19,'ߝߐ߲ߝߐ߲ߣߍ߲','animal'),
            image.player(20,'ߘߎߥߊ߮','animal'),       
             ],
    
    'ߕߐ߮': [
            'ߛߏߛߏ߮',
            'xxxx',
            'xxx',
            'ߕߏߕߏ߮',
            'ߦߌߣߍ߮',
            'ߛߊߡߊ߮',
            'ߖߌߙߌߛߎ߲ߓߊ߮',
            'ߛߊ߮',
            'ߥߊߙߊ߮',
            'ߓߊߛߊ߮',
            'ߒߕߏߙߌ',
            'ߓߊ߮',
            'ߓߊ߲ߓߊ߮',
            'ߝߐ߲ߝߐ߲ߣߍ߲',
            'ߘߎߥߊ߮',
            'ߒߕߏߙߌ',
            'ߓߊ߮',
            'ߓߊ߲ߓߊ߮',
            'ߝߐ߲ߝߐ߲ߣߍ߲',
            'ߘߎߥߊ߮',        
             ],
    
    'ߞߊ߲': 
    [
    sound.player(1,'vowel','vowel'),       
    sound.player(2,'vowel','vowel'),
    sound.player(3,'VOWEL','vowel'),
    sound.player(4,'VOWEL','vowel'),
    sound.player(5,'vowel','vowel'),
    sound.player(6,'vowel','vowel'), 
    sound.player(7,'vowel','vowel'),
    sound.player(8,'vowel','vowel'),
    sound.player(9,'vowel','vowel'),
    sound.player(10,'vowel','vowel'),  
    sound.player(11,'vowel','vowel'),
    sound.player(12,'vowel','vowel'),
    sound.player(13,'vowel','vowel'), 
    sound.player(14,'vowel','vowel'),
    sound.player(15,'vowel','vowel'),    
    sound.player(11,'vowel','vowel'),
    sound.player(12,'vowel','vowel'),
    sound.player(13,'vowel','vowel'), 
    sound.player(14,'vowel','vowel'),
    sound.player(15,'vowel','vowel'),         
    ],

        'Name': [
            'Mosquito',
            'xxx',
            'Chameleon',
            'Rat',
            'Mouse',
            'Elephant',
            'Hippopotamus',
            'Snake',
            'Lion',
            'Lizard',
            'Frog',
            'Goat',
            'Crododile',
            'Viper',
            'Vulture',
            'Frog',
            'Goat',
            'Crododile',
            'Viper',
            'Vulture'            
             ],
    
    'Pronounciation': 
    [
    sound.player(1,'vowel','vowel'),       
    sound.player(2,'vowel','vowel'),
    sound.player(3,'VOWEL','vowel'),
    sound.player(4,'VOWEL','vowel'),
    sound.player(5,'vowel','vowel'),
    sound.player(6,'vowel','vowel'), 
    sound.player(7,'vowel','vowel'),
    sound.player(8,'vowel','vowel'),
    sound.player(9,'vowel','vowel'),
    sound.player(10,'vowel','vowel'),  
    sound.player(11,'vowel','vowel'),
    sound.player(12,'vowel','vowel'),
    sound.player(13,'vowel','vowel'), 
    sound.player(14,'vowel','vowel'),
    sound.player(15,'vowel','vowel'),  
    sound.player(11,'vowel','vowel'),
    sound.player(12,'vowel','vowel'),
    sound.player(13,'vowel','vowel'), 
    sound.player(14,'vowel','vowel'),
    sound.player(15,'vowel','vowel'),
    ]
})


HTML(df.to_html(escape=False,index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ߖߊ</th>
#       <th>ߕߐ߮</th>
#       <th>ߞߊ߲</th>
#       <th>Name</th>
#       <th>Pronounciation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/image/animal/1.jpg" alt="ߛߏߛߏ߮" width="150" height="150"></td>
#       <td>ߛߏߛߏ߮</td>
#       <td><audio controls style="width:150px">\n                    <source src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/sound/vowel/1.mp3" type="audio/mpeg">\n                </audio></td>
#       <td>Mosquito</td>
#       <td><audio controls style="width:150px">\n                    <source src="https://github.com/kukufuckingkan/mandenkan_media/raw/refs/heads/main/sound/vowel/1.mp3" type="audio/mpeg">\n                </audio></td>
#     </tr>
#     <tr>
# ...
