# %%
# star

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['Planet', 'nko', 'pronounciation', 'nko pronouncition','image']
values = [
    ['Sun', '', '','',''],
    ['Moon', '', '','',''],
    ['Earth', '', '','',''],
    ['Jupiter', '', '','',''],
    ['Saturn', '', '','',''],
    ['Uranus', '', '','',''],
    ['Neptune', '', '','',''],
    ['Mars', '', '','',''],
    ['Pluto', '', '','',''],
    ['Venus', '', '','',''],
    ['Mercury', '', '','',''],
    ['Ceres', '', '','',''],
    ['Haumea', '', '','',''],
    ['Comet', '', '','',''],
    ['Asteroid', '', '','',''],
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Planet</th>
#       <th>nko</th>
#       <th>pronounciation</th>
#       <th>nko pronouncition</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sun</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Moon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Earth</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jupiter</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Saturn</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
# Zodiac

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['Zodiac', 'nko', 'pronounciation', 'nko pronouncition','image']
values = [
    ['Aquarius', '', '','',''],
    ['Leo', '', '','',''],
    ['Sagittarius', '', '','',''],
    ['Gemini', '', '','',''],
    ['Taurus', '', '','',''],
    ['Virgo', '', '','',''],
    ['Libra', '', '','',''],
    ['Scorpio','','',''],
    ['Aries', '', '','',''],
    ['Pisces', '', '','',''],
    ['Capricorn', '', '','',''],
    ['Cancer', '', '','',''],
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Zodiac</th>
#       <th>nko</th>
#       <th>pronounciation</th>
#       <th>nko pronouncition</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Aquarius</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Leo</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sagittarius</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Gemini</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Taurus</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Chinese zodiac

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['Zodiac', 'nko', 'pronounciation', 'nko pronouncition','image']
values = [
    ['Rat', '', '','',''],
    ['Ox', '', '','',''],
    ['Rabbit', '', '','',''],
    ['Dragon', '', '','',''],
    ['Snake', '', '','',''],
    ['Horse', '', '','',''],
    ['Goat', '', '','',''],
    ['Monkey','','',''],
    ['Rooster', '', '','',''],
    ['Dog', '', '','',''],
    ['Pig', '', '','',''],
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Zodiac</th>
#       <th>nko</th>
#       <th>pronounciation</th>
#       <th>nko pronouncition</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Rat</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ox</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Rabbit</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Dragon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Snake</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
# https://www.thecornrow.com/blogs/news/african-astrology-the-ancient-divination-tool-that-may-resonate-with-you?srsltid=AfmBOorUeh4BIMnIYSbIarfiKHuEg7r7RGvBUfFYpU-ngcUfwdqDpjUv

# %%
# https://twofeathers.co.uk/pages/native-american-astrology?srsltid=AfmBOopbS04mYVp6tOSq2JPNG8HBEza0bl4WRWnsUkYNSK88TwY7_YMZ

# %%
# Amerindian

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['Zodiac', 'nko', 'pronounciation', 'nko pronouncition','image']
values = [
    ['Red Hawk', '', '','',''],
    ['Beaver', '', '','',''],
    ['Deer', '', '','',''],
    ['Woodpecker', '', '','',''],
    ['Salmon', '', '','',''],
    ['Brown Bear', '', '','',''],
    ['Raven', '', '','',''],
    ['Snake','','',''],
    ['Snow Goose', '', '','',''],
    ['Otter', '', '','',''],
    ['Wolf', '', '','',''],
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Zodiac</th>
#       <th>nko</th>
#       <th>pronounciation</th>
#       <th>nko pronouncition</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Red Hawk</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Beaver</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Deer</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Woodpecker</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Salmon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %%
# Constellation

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['Latin', 'English Name', 'pronounciation', 'nko pronouncition','image']
values = [
    ['Andromeda', 'Princess of Ethiopia', '','',''],
    ['Antila', 'Air Pump', '','',''],
    ['Apus', 'Bird Of Paradise', '','',''],
    ['Aquarius', 'Water Bearer', '','',''],    
    ['Ara', 'Altar', '','',''],
    ['Aries', 'Ram', '','',''],
    ['Auriga', 'Charioteer', '','',''],
    ['Bootes', 'Herdsman', '','',''],
    ['Caelum','Graving Tool','',''],
    ['Camelopardalis', 'Giraffe', '','',''],
    ['Cancer', 'Crab', '','',''],
    ['Canes Venatici', 'Hunting dogs', '','',''],
    ['Canis Major', 'Big dog', '','',''],
    ['Capricornus', 'Sea goat', '','',''],
    ['Carina', "Keel of Argonauts' ship", '','',''],
    ['Cassiopeia', 'Queen of Ethiopia', '','',''],
    ['Centaurus', 'Centaur', '','',''],
    ['Cepheus', 'Sea of Monster (Whale)', '','',''],
    ['Chamaeleon', 'Chameleon', '','',''],
    ['Cassiopeia', 'Queen of Ethiopia', '','',''],
    ['Circinus', 'Compasses', '','',''],
    ['Columba', 'Dove', '','',''],
    ['Coma Berenices', 'Berenice's hair', '','',''],
    ['Corona Australis', 'Souther crown', '','',''],
    ['Corona Borealis', 'Norther Crown', '','',''],
    ['Corvus', 'Crow', '','',''],
    ['Crater', 'Cup', '','',''],
    ['Crux', 'Cross (southern', '','',''],  
    ['Cygus', 'Swan', '','',''],
    ['Delphinus', 'Porpoise', '','',''],  
    ['Darado', 'Swordfish', '','',''], 
    ['Draco', 'Dragon', '','',''], 
    ['Equuleus', 'Little horse', '','',''], 
    ['Eridanus', 'River', '','',''],
    ['Fornax', 'River', '','',''], 
    ['Eridanus', 'Furnace', '','',''], 
    ['Gemini', 'Twins', '','',''], 
    ['Hercules', 'Herculus, son of Zeus', '','',''], 
    ['Herologium', 'Clock', '','',''], 
    ['Hydra', 'Sea serpent', '','',''], 
    ['Hydrus', 'Water snake', '','',''], 
    ['Indus', 'Indian', '','',''], 
    ['Lacera', 'Lizard', '','',''],
    ['Leo', 'Lion', '','',''],
    ['Leo Minor', 'Little Lion', '','',''],
    ['Lepus', 'Hare', '','',''],
    ['Lynx', 'Lynx', '','',''],
    ['Lyra', 'Lyre of harp', '','',''],
    ['Mensa', 'Table mountain', '','',''],
    ['Microscopium', 'Indian', '','',''],  


    ['Monoceros', 'Unicorn', '','',''],    
    ['Musca', 'fly', '','',''],    
    ['Norma', 'Carpenter's level', '','',''],    
    ['Octans', 'Octant', '','',''],        
    ['Ophiuchus', 'Holder of serpent', '','',''],    
    ['Orion', 'Orion, the hunter', '','',''],    
    ['Pavo', 'Peacock', '','',''],
    ['Pegasus', 'Pegasus, the winged horse', '','',''],    
    ['Perseus', 'Perseus,here who saved Andromeda', '','',''],    
    ['Phoenix', 'Phoenix', '','',''],    
    ['Pictor', 'Easel', '','',''],    
    ['Pisces', 'Fishes', '','',''],    
    ['Piscis Austrinus', 'Southern fish', '','',''],     
    ['Puppis', 'Stern of the Argonauts'ship', '','',''],    
    ['Pyxis', 'Compass of the argonauts' ship', '','',''],    
    ['Recticulum', 'Net', '','',''],    
    ['Sagitta', 'Arrow', '','',''],    
    ['Sagittarius', 'Archer', '','',''],    
    ['Scorplus', 'Scorpion', '','',''],    
    ['Sculptor', 'Sculptor's tool', '','',''],    
    ['Scutum', 'Shield', '','',''],        


    ['Serpens', 'Serpent', '','',''], 
    ['Sextant', 'Sextant', '','',''], 
    ['Taurus', 'Bull', '','',''], 
    ['Telescopium', 'Telescope', '','',''], 
    ['Triangulum', 'Triangle', '','',''], 
    ['Triangulum Australe', 'Southern triagle', '','',''], 
    ['Tucana', 'Toucan', '','',''], 
    ['Ursa Major', 'Big bear', '','',''], 
    ['Vela', 'Sail of the Argonauts' ship', '','',''], 
    ['Virgo', 'Virgin', '','',''], 
    ['Volans', 'Flying firsh', '','',''], 
    ['Vulpecula', 'Fox', '','',''],     
    




    


    
    



        
    
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

HTML(df.to_html(escape=False))
