# %% [markdown]
# # Prefix
# ## ߦߍߕߎ߲

# %%
# HIDDEN
import pandas as pd
from IPython.display import HTML

# Define headers and values (as lists)
headers = ['name', 'nko', 'pronounciation', 'nko pronouncition']
values = [
    ['tun', 'Connect', '',''],
    ['tunli', '', '',''],
    ['tunni', 'Connection', '',''],    
    ['tunta', 'Connectable', '',''],
    ['tunna', '', '',''],
    ['tunma', 'Connector (person)', '',''],
    ['tunnen', '', '',''],
    ['tuntoh', '', '',''], 
    ['tunra', '', '',''],
    ['tundi', '', '',''],
    ['faa', '', '',''],  
]

# Create the DataFrame with headers and rows of values
df = pd.DataFrame(values, columns=headers)

# Function to color the second row (index 2) in green
def color_row_green(row):
    #print(row)
    return ['background-color: lightgreen'] * len(row) if row.name == 2 else [''] * len(row)

# Apply the row coloring
styled_df = df.style.apply(color_row_green, axis=1)


HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>nko</th>
#       <th>pronounciation</th>
#       <th>nko pronouncition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>tun</td>
#       <td>Connect</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>tunli</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>tunni</td>
#       <td>Connection</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>tunta</td>
#       <td>Connectable</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>tunna</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>tunma</td>
#       <td>Connector (person)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>tunnen</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>tuntoh</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>tunra</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>tundi</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>faa</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
